# %%
from torch.utils.data import DataLoader
from torch.utils.data import Subset
from IPython.display import HTML
from torchvision import models
from scipy import linalg
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
import time

# %%
transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ])

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
dataset = datasets.CIFAR10(root="HW4/dataset/CIFAR10data", download=True,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))
# Out:
# cuda
# Files already downloaded and verified

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,shuffle=True, num_workers=2)
real_batch = next(iter(dataloader))
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            self.Gnet(channels_noise, features_g * 16, 4, 1, 0),
            self.Gnet(features_g * 16, features_g * 8, 4, 2, 1),
            self.Gnet(features_g * 8, features_g * 4, 4, 2, 1),
            self.Gnet(features_g * 4, features_g * 2, 4, 2, 1),
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            nn.Tanh(),
        )

    def Gnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels,momentum=0.9),
            nn.ReLU(),
        )
    def forward(self, x):
        return self.net(x)

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self.Dnet(features_d, features_d * 2, 4, 2, 1),
            self.Dnet(features_d * 2, features_d * 4, 4, 2, 1),
            self.Dnet(features_d * 4, features_d * 8, 4, 2, 1),
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def Dnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
gen = Generator(channels_noise = 100, channels_img = 3, features_g = 64).to(device)
disc = Discriminator(channels_img = 3, features_d = 64).to(device)

# %%
for m in gen.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)
for m in disc.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)
leaning_rate = 2e-4
criterion = nn.BCELoss()
fixed_noise = torch.randn(32, 100, 1, 1).to(device)
step = 0

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""

    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
		'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        # Block 0: input to maxpool1
        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))

        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        # Block 2: maxpool2 to aux classifier
        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        # Block 3: aux classifier to final avgpool
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp

# %%
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()
# Out:
# /home/skomara/.local/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/skomara/.local/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    active=np.empty((len(images), dims))
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    predicted = model(batch)[0]
    if predicted.size(2) != 1 or predicted.size(3) != 1:
        predicted = adaptive_avg_pool2d(predicted, output_size=(1, 1))
    active= predicted.cpu().data.numpy().reshape(predicted.size(0), -1)    
    mean = np.mean(active, axis=0)
    sigma = np.cov(active, rowvar=False)
    return mean, sigma

# %%
def calculate_frechet_distance(mu_real, sigma_real, mu_fake, sigma_fake, eps=1e-6):
    sigma_real = np.atleast_2d(sigma_real)
    sigma_fake = np.atleast_2d(sigma_fake)
    mu_real = np.atleast_1d(mu_real)
    mu_fake = np.atleast_1d(mu_fake)
    assert mu_real.shape == mu_fake.shape, \
        'Real and fake mean vectors have different lengths'
    assert sigma_real.shape == sigma_fake.shape, \
        'Real and fake covariances have different dimensions'
    diff = mu_real - mu_fake
    covmean, _ = linalg.sqrtm(sigma_real.dot(sigma_fake), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('FID calculation produces singular product; '
               'adding {} to diagonal of cov estimates').format(eps)
        print(msg)
        offset = np.eye(sigma_real.shape[0]) * eps
        covmean = linalg.sqrtm((sigma_real + offset).dot(sigma_fake + offset))
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real
    tr_covmean = np.trace(covmean)
    return (diff.dot(diff) + np.trace(sigma_real) + np.trace(sigma_fake) - 2 * tr_covmean)

# %%
def calculate_fretchet(real_images, fake_images, model):
    mu_real, std_real = calculate_activation_statistics(real_images, model, cuda=True)
    mu_fake, std_fake = calculate_activation_statistics(fake_images, model, cuda=True)
    fd_value = calculate_frechet_distance(mu_real, std_real, mu_fake, std_fake)
    return fd_value

# %%
gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
GLoss = []
DLoss = []
image_list = []
fd_list = []
i = 0

gen_optimizer = optim.Adam(gen.parameters(), lr=leaning_rate, betas=(0.5, 0.999))
disc_optimizer = optim.Adam(disc.parameters(), lr=leaning_rate, betas=(0.5, 0.999))

# %%
print("!!Training Started!!")
time_start = time.time()
num_epochs = 50
for epoch in range(num_epochs):
    epoch = epoch+1

    for batch_idx, data in enumerate(dataloader,0):
        #training with real batch
        real = data[0].to(device)
        noise = torch.randn(128, 100, 1, 1).to(device)
        fake = gen(noise) #genrator img data

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward()
        disc_optimizer.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        gen_optimizer.step()

        # Print losses occasionally and print to tensorboard
        if batch_idx % 100 == 0:
            print(
                    f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                      Loss Discriminator: {loss_disc:.3f}, loss Generator: {loss_gen:.3f}"
                )
            #saving the losses for every 100 batch
            GLoss.append(loss_gen.detach().cpu())
            DLoss.append(loss_disc.detach().cpu())

        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (i % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            image_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        i += 1
    fretchet_dist = calculate_fretchet(real, fake, model)
    print('Fretchet Distance: ', fretchet_dist)
    fd_list.append(fretchet_dist)
# Out:
# !!Training Started!!
# Epoch [1/50] Batch 0/1563                       Loss Discriminator: 0.694, loss Generator: 0.693
# Epoch [1/50] Batch 100/1563                       Loss Discriminator: 0.155, loss Generator: 2.166
# Epoch [1/50] Batch 200/1563                       Loss Discriminator: 0.120, loss Generator: 3.606
# Epoch [1/50] Batch 300/1563                       Loss Discriminator: 0.282, loss Generator: 2.109
# Epoch [1/50] Batch 400/1563                       Loss Discriminator: 0.404, loss Generator: 1.973
# Epoch [1/50] Batch 500/1563                       Loss Discriminator: 0.316, loss Generator: 2.042
# Epoch [1/50] Batch 600/1563                       Loss Discriminator: 0.543, loss Generator: 1.546
# Epoch [1/50] Batch 700/1563                       Loss Discriminator: 0.569, loss Generator: 1.648
# Epoch [1/50] Batch 800/1563                       Loss Discriminator: 0.648, loss Generator: 0.981
# Epoch [1/50] Batch 900/1563                       Loss Discriminator: 0.686, loss Generator: 2.161
# Epoch [1/50] Batch 1000/1563                       Loss Discriminator: 0.562, loss Generator: 1.091
# Epoch [1/50] Batch 1100/1563                       Loss Discriminator: 0.633, loss Generator: 1.041
# Epoch [1/50] Batch 1200/1563                       Loss Discriminator: 0.611, loss Generator: 0.982
# Epoch [1/50] Batch 1300/1563                       Loss Discriminator: 0.602, loss Generator: 1.160
# Epoch [1/50] Batch 1400/1563                       Loss Discriminator: 0.569, loss Generator: 1.152
# Epoch [1/50] Batch 1500/1563                       Loss Discriminator: 0.738, loss Generator: 0.939
# Fretchet Distance:  376.11707971052925
# Epoch [2/50] Batch 0/1563                       Loss Discriminator: 0.730, loss Generator: 1.139
# Epoch [2/50] Batch 100/1563                       Loss Discriminator: 0.750, loss Generator: 1.169
# Epoch [2/50] Batch 200/1563                       Loss Discriminator: 0.750, loss Generator: 2.078
# Epoch [2/50] Batch 300/1563                       Loss Discriminator: 0.432, loss Generator: 1.702
# Epoch [2/50] Batch 400/1563                       Loss Discriminator: 0.492, loss Generator: 1.648
# Epoch [2/50] Batch 500/1563                       Loss Discriminator: 0.861, loss Generator: 3.512
# Epoch [2/50] Batch 600/1563                       Loss Discriminator: 0.618, loss Generator: 1.116
# Epoch [2/50] Batch 700/1563                       Loss Discriminator: 0.606, loss Generator: 1.097
# Epoch [2/50] Batch 800/1563                       Loss Discriminator: 0.657, loss Generator: 0.966
# Epoch [2/50] Batch 900/1563                       Loss Discriminator: 0.599, loss Generator: 0.918
# Epoch [2/50] Batch 1000/1563                       Loss Discriminator: 0.642, loss Generator: 0.904
# Epoch [2/50] Batch 1100/1563                       Loss Discriminator: 0.590, loss Generator: 1.034
# Epoch [2/50] Batch 1200/1563                       Loss Discriminator: 0.599, loss Generator: 0.986
# Epoch [2/50] Batch 1300/1563                       Loss Discriminator: 0.641, loss Generator: 0.919
# Epoch [2/50] Batch 1400/1563                       Loss Discriminator: 0.588, loss Generator: 1.135
# Epoch [2/50] Batch 1500/1563                       Loss Discriminator: 0.511, loss Generator: 1.109
# Fretchet Distance:  315.39718447826533
# Epoch [3/50] Batch 0/1563                       Loss Discriminator: 0.813, loss Generator: 0.939
# Epoch [3/50] Batch 100/1563                       Loss Discriminator: 0.602, loss Generator: 1.166
# Epoch [3/50] Batch 200/1563                       Loss Discriminator: 0.631, loss Generator: 1.073
# Epoch [3/50] Batch 300/1563                       Loss Discriminator: 0.564, loss Generator: 0.924
# Epoch [3/50] Batch 400/1563                       Loss Discriminator: 0.651, loss Generator: 1.137
# Epoch [3/50] Batch 500/1563                       Loss Discriminator: 0.652, loss Generator: 0.891
# Epoch [3/50] Batch 600/1563                       Loss Discriminator: 0.604, loss Generator: 1.042
# Epoch [3/50] Batch 700/1563                       Loss Discriminator: 0.660, loss Generator: 0.978
# Epoch [3/50] Batch 800/1563                       Loss Discriminator: 0.660, loss Generator: 0.921
# Epoch [3/50] Batch 900/1563                       Loss Discriminator: 0.709, loss Generator: 0.843
# Epoch [3/50] Batch 1000/1563                       Loss Discriminator: 0.713, loss Generator: 0.969
# Epoch [3/50] Batch 1100/1563                       Loss Discriminator: 0.686, loss Generator: 0.815
# Epoch [3/50] Batch 1200/1563                       Loss Discriminator: 0.613, loss Generator: 0.826
# Epoch [3/50] Batch 1300/1563                       Loss Discriminator: 0.699, loss Generator: 0.887
# Epoch [3/50] Batch 1400/1563                       Loss Discriminator: 0.679, loss Generator: 0.920
# Epoch [3/50] Batch 1500/1563                       Loss Discriminator: 0.622, loss Generator: 0.909
# Fretchet Distance:  273.2201573237645
# Epoch [4/50] Batch 0/1563                       Loss Discriminator: 0.682, loss Generator: 1.005
# Epoch [4/50] Batch 100/1563                       Loss Discriminator: 0.645, loss Generator: 0.986
# Epoch [4/50] Batch 200/1563                       Loss Discriminator: 0.708, loss Generator: 0.789
# Epoch [4/50] Batch 300/1563                       Loss Discriminator: 0.656, loss Generator: 0.823
# Epoch [4/50] Batch 400/1563                       Loss Discriminator: 0.667, loss Generator: 1.314
# Epoch [4/50] Batch 500/1563                       Loss Discriminator: 0.585, loss Generator: 0.822
# Epoch [4/50] Batch 600/1563                       Loss Discriminator: 0.634, loss Generator: 0.838
# Epoch [4/50] Batch 700/1563                       Loss Discriminator: 0.654, loss Generator: 0.848
# Epoch [4/50] Batch 800/1563                       Loss Discriminator: 0.607, loss Generator: 0.919
# Epoch [4/50] Batch 900/1563                       Loss Discriminator: 0.631, loss Generator: 1.039
# Epoch [4/50] Batch 1000/1563                       Loss Discriminator: 0.623, loss Generator: 0.721
# Epoch [4/50] Batch 1100/1563                       Loss Discriminator: 0.599, loss Generator: 0.829
# Epoch [4/50] Batch 1200/1563                       Loss Discriminator: 0.614, loss Generator: 0.983
# Epoch [4/50] Batch 1300/1563                       Loss Discriminator: 0.637, loss Generator: 1.159
# Epoch [4/50] Batch 1400/1563                       Loss Discriminator: 0.626, loss Generator: 1.101
# Epoch [4/50] Batch 1500/1563                       Loss Discriminator: 0.611, loss Generator: 0.903
# Fretchet Distance:  258.93539400557995
# Epoch [5/50] Batch 0/1563                       Loss Discriminator: 0.645, loss Generator: 0.856
# Epoch [5/50] Batch 100/1563                       Loss Discriminator: 0.582, loss Generator: 0.822
# Epoch [5/50] Batch 200/1563                       Loss Discriminator: 0.656, loss Generator: 0.831
# Epoch [5/50] Batch 300/1563                       Loss Discriminator: 0.640, loss Generator: 0.872
# Epoch [5/50] Batch 400/1563                       Loss Discriminator: 0.620, loss Generator: 1.085
# Epoch [5/50] Batch 500/1563                       Loss Discriminator: 0.741, loss Generator: 0.717
# Epoch [5/50] Batch 600/1563                       Loss Discriminator: 0.632, loss Generator: 1.061
# Epoch [5/50] Batch 700/1563                       Loss Discriminator: 0.637, loss Generator: 0.953
# Epoch [5/50] Batch 800/1563                       Loss Discriminator: 0.582, loss Generator: 1.147
# Epoch [5/50] Batch 900/1563                       Loss Discriminator: 0.693, loss Generator: 1.085
# Epoch [5/50] Batch 1000/1563                       Loss Discriminator: 0.664, loss Generator: 0.985
# Epoch [5/50] Batch 1100/1563                       Loss Discriminator: 0.597, loss Generator: 1.021
# Epoch [5/50] Batch 1200/1563                       Loss Discriminator: 0.651, loss Generator: 0.824
# Epoch [5/50] Batch 1300/1563                       Loss Discriminator: 0.672, loss Generator: 1.021
# Epoch [5/50] Batch 1400/1563                       Loss Discriminator: 0.615, loss Generator: 0.745
# Epoch [5/50] Batch 1500/1563                       Loss Discriminator: 0.699, loss Generator: 0.803
# Fretchet Distance:  246.17823376733799
# Epoch [6/50] Batch 0/1563                       Loss Discriminator: 0.593, loss Generator: 0.846
# Epoch [6/50] Batch 100/1563                       Loss Discriminator: 0.622, loss Generator: 0.781
# Epoch [6/50] Batch 200/1563                       Loss Discriminator: 0.623, loss Generator: 0.866
# Epoch [6/50] Batch 300/1563                       Loss Discriminator: 0.594, loss Generator: 0.800
# Epoch [6/50] Batch 400/1563                       Loss Discriminator: 0.649, loss Generator: 0.942
# Epoch [6/50] Batch 500/1563                       Loss Discriminator: 0.706, loss Generator: 0.985
# Epoch [6/50] Batch 600/1563                       Loss Discriminator: 0.635, loss Generator: 0.940
# Epoch [6/50] Batch 700/1563                       Loss Discriminator: 0.663, loss Generator: 0.738
# Epoch [6/50] Batch 800/1563                       Loss Discriminator: 0.602, loss Generator: 1.127
# Epoch [6/50] Batch 900/1563                       Loss Discriminator: 0.573, loss Generator: 1.044
# Epoch [6/50] Batch 1000/1563                       Loss Discriminator: 0.621, loss Generator: 0.821
# Epoch [6/50] Batch 1100/1563                       Loss Discriminator: 0.593, loss Generator: 0.905
# Epoch [6/50] Batch 1200/1563                       Loss Discriminator: 0.625, loss Generator: 1.000
# Epoch [6/50] Batch 1300/1563                       Loss Discriminator: 0.647, loss Generator: 0.971
# Epoch [6/50] Batch 1400/1563                       Loss Discriminator: 0.585, loss Generator: 1.025
# Epoch [6/50] Batch 1500/1563                       Loss Discriminator: 0.689, loss Generator: 1.343
# Fretchet Distance:  254.53799665856963
# Epoch [7/50] Batch 0/1563                       Loss Discriminator: 0.584, loss Generator: 1.264
# Epoch [7/50] Batch 100/1563                       Loss Discriminator: 0.703, loss Generator: 0.725
# Epoch [7/50] Batch 200/1563                       Loss Discriminator: 0.632, loss Generator: 0.993
# Epoch [7/50] Batch 300/1563                       Loss Discriminator: 0.607, loss Generator: 0.958
# Epoch [7/50] Batch 400/1563                       Loss Discriminator: 0.585, loss Generator: 1.058
# Epoch [7/50] Batch 500/1563                       Loss Discriminator: 0.586, loss Generator: 1.029
# Epoch [7/50] Batch 600/1563                       Loss Discriminator: 0.835, loss Generator: 1.208
# Epoch [7/50] Batch 700/1563                       Loss Discriminator: 0.625, loss Generator: 0.919
# Epoch [7/50] Batch 800/1563                       Loss Discriminator: 0.528, loss Generator: 1.021
# Epoch [7/50] Batch 900/1563                       Loss Discriminator: 0.674, loss Generator: 1.264
# Epoch [7/50] Batch 1000/1563                       Loss Discriminator: 0.694, loss Generator: 1.012
# Epoch [7/50] Batch 1100/1563                       Loss Discriminator: 0.634, loss Generator: 0.893
# Epoch [7/50] Batch 1200/1563                       Loss Discriminator: 0.539, loss Generator: 0.934
# Epoch [7/50] Batch 1300/1563                       Loss Discriminator: 0.618, loss Generator: 1.013
# Epoch [7/50] Batch 1400/1563                       Loss Discriminator: 0.615, loss Generator: 0.890
# Epoch [7/50] Batch 1500/1563                       Loss Discriminator: 0.592, loss Generator: 1.054
# Fretchet Distance:  246.3120955480457
# Epoch [8/50] Batch 0/1563                       Loss Discriminator: 0.567, loss Generator: 1.073
# Epoch [8/50] Batch 100/1563                       Loss Discriminator: 0.545, loss Generator: 0.953
# Epoch [8/50] Batch 200/1563                       Loss Discriminator: 0.612, loss Generator: 0.992
# Epoch [8/50] Batch 300/1563                       Loss Discriminator: 0.645, loss Generator: 1.447
# Epoch [8/50] Batch 400/1563                       Loss Discriminator: 0.539, loss Generator: 1.066
# Epoch [8/50] Batch 500/1563                       Loss Discriminator: 0.646, loss Generator: 0.897
# Epoch [8/50] Batch 600/1563                       Loss Discriminator: 0.627, loss Generator: 0.845
# Epoch [8/50] Batch 700/1563                       Loss Discriminator: 0.599, loss Generator: 0.961
# Epoch [8/50] Batch 800/1563                       Loss Discriminator: 0.576, loss Generator: 0.918
# Epoch [8/50] Batch 900/1563                       Loss Discriminator: 0.594, loss Generator: 1.245
# Epoch [8/50] Batch 1000/1563                       Loss Discriminator: 0.574, loss Generator: 0.673
# Epoch [8/50] Batch 1100/1563                       Loss Discriminator: 0.811, loss Generator: 1.056
# Epoch [8/50] Batch 1200/1563                       Loss Discriminator: 0.676, loss Generator: 0.812
# Epoch [8/50] Batch 1300/1563                       Loss Discriminator: 0.469, loss Generator: 1.348
# Epoch [8/50] Batch 1400/1563                       Loss Discriminator: 0.504, loss Generator: 0.999
# Epoch [8/50] Batch 1500/1563                       Loss Discriminator: 0.625, loss Generator: 1.029
# Fretchet Distance:  258.81546256700415
# Epoch [9/50] Batch 0/1563                       Loss Discriminator: 0.456, loss Generator: 0.784
# Epoch [9/50] Batch 100/1563                       Loss Discriminator: 0.586, loss Generator: 1.014
# Epoch [9/50] Batch 200/1563                       Loss Discriminator: 0.575, loss Generator: 0.917
# Epoch [9/50] Batch 300/1563                       Loss Discriminator: 0.512, loss Generator: 1.262
# Epoch [9/50] Batch 400/1563                       Loss Discriminator: 0.656, loss Generator: 1.008
# Epoch [9/50] Batch 500/1563                       Loss Discriminator: 0.552, loss Generator: 0.854
# Epoch [9/50] Batch 600/1563                       Loss Discriminator: 0.662, loss Generator: 0.947
# Epoch [9/50] Batch 700/1563                       Loss Discriminator: 0.607, loss Generator: 1.007
# Epoch [9/50] Batch 800/1563                       Loss Discriminator: 0.531, loss Generator: 1.239
# Epoch [9/50] Batch 900/1563                       Loss Discriminator: 0.547, loss Generator: 1.244
# Epoch [9/50] Batch 1000/1563                       Loss Discriminator: 0.588, loss Generator: 0.876
# Epoch [9/50] Batch 1100/1563                       Loss Discriminator: 0.598, loss Generator: 1.026
# Epoch [9/50] Batch 1200/1563                       Loss Discriminator: 0.666, loss Generator: 0.996
# Epoch [9/50] Batch 1300/1563                       Loss Discriminator: 0.688, loss Generator: 0.809
# Epoch [9/50] Batch 1400/1563                       Loss Discriminator: 0.575, loss Generator: 1.093
# Epoch [9/50] Batch 1500/1563                       Loss Discriminator: 0.570, loss Generator: 0.874
# Fretchet Distance:  266.069533214292
# Epoch [10/50] Batch 0/1563                       Loss Discriminator: 0.649, loss Generator: 0.895
# Epoch [10/50] Batch 100/1563                       Loss Discriminator: 0.540, loss Generator: 1.087
# Epoch [10/50] Batch 200/1563                       Loss Discriminator: 0.676, loss Generator: 0.748
# Epoch [10/50] Batch 300/1563                       Loss Discriminator: 0.533, loss Generator: 1.086
# Epoch [10/50] Batch 400/1563                       Loss Discriminator: 0.715, loss Generator: 0.842
# Epoch [10/50] Batch 500/1563                       Loss Discriminator: 0.884, loss Generator: 1.314
# Epoch [10/50] Batch 600/1563                       Loss Discriminator: 0.668, loss Generator: 1.011
# Epoch [10/50] Batch 700/1563                       Loss Discriminator: 0.528, loss Generator: 1.116
# Epoch [10/50] Batch 800/1563                       Loss Discriminator: 0.590, loss Generator: 1.075
# Epoch [10/50] Batch 900/1563                       Loss Discriminator: 0.500, loss Generator: 1.216
# Epoch [10/50] Batch 1000/1563                       Loss Discriminator: 0.627, loss Generator: 0.847
# Epoch [10/50] Batch 1100/1563                       Loss Discriminator: 0.436, loss Generator: 1.112
# Epoch [10/50] Batch 1200/1563                       Loss Discriminator: 0.643, loss Generator: 0.815
# Epoch [10/50] Batch 1300/1563                       Loss Discriminator: 0.584, loss Generator: 1.149
# Epoch [10/50] Batch 1400/1563                       Loss Discriminator: 0.559, loss Generator: 0.846
# Epoch [10/50] Batch 1500/1563                       Loss Discriminator: 0.661, loss Generator: 0.949
# Fretchet Distance:  259.6018229034413
# Epoch [11/50] Batch 0/1563                       Loss Discriminator: 0.629, loss Generator: 1.116
# Epoch [11/50] Batch 100/1563                       Loss Discriminator: 0.540, loss Generator: 1.227
# Epoch [11/50] Batch 200/1563                       Loss Discriminator: 0.552, loss Generator: 1.045
# Epoch [11/50] Batch 300/1563                       Loss Discriminator: 0.518, loss Generator: 0.879
# Epoch [11/50] Batch 400/1563                       Loss Discriminator: 0.588, loss Generator: 1.031
# Epoch [11/50] Batch 500/1563                       Loss Discriminator: 0.781, loss Generator: 1.596
# Epoch [11/50] Batch 600/1563                       Loss Discriminator: 0.546, loss Generator: 0.790
# Epoch [11/50] Batch 700/1563                       Loss Discriminator: 0.766, loss Generator: 1.207
# Epoch [11/50] Batch 800/1563                       Loss Discriminator: 0.615, loss Generator: 1.301
# Epoch [11/50] Batch 900/1563                       Loss Discriminator: 0.641, loss Generator: 0.929
# Epoch [11/50] Batch 1000/1563                       Loss Discriminator: 0.654, loss Generator: 1.485
# Epoch [11/50] Batch 1100/1563                       Loss Discriminator: 0.453, loss Generator: 1.030
# Epoch [11/50] Batch 1200/1563                       Loss Discriminator: 0.516, loss Generator: 1.361
# Epoch [11/50] Batch 1300/1563                       Loss Discriminator: 0.619, loss Generator: 1.160
# Epoch [11/50] Batch 1400/1563                       Loss Discriminator: 0.565, loss Generator: 1.441
# Epoch [11/50] Batch 1500/1563                       Loss Discriminator: 0.611, loss Generator: 0.935
# Fretchet Distance:  255.09811800209786
# Epoch [12/50] Batch 0/1563                       Loss Discriminator: 0.536, loss Generator: 1.183
# Epoch [12/50] Batch 100/1563                       Loss Discriminator: 0.618, loss Generator: 0.996
# Epoch [12/50] Batch 200/1563                       Loss Discriminator: 0.639, loss Generator: 0.997
# Epoch [12/50] Batch 300/1563                       Loss Discriminator: 0.526, loss Generator: 1.156
# Epoch [12/50] Batch 400/1563                       Loss Discriminator: 0.510, loss Generator: 0.936
# Epoch [12/50] Batch 500/1563                       Loss Discriminator: 0.589, loss Generator: 0.995
# Epoch [12/50] Batch 600/1563                       Loss Discriminator: 0.526, loss Generator: 1.557
# Epoch [12/50] Batch 700/1563                       Loss Discriminator: 0.437, loss Generator: 1.161
# Epoch [12/50] Batch 800/1563                       Loss Discriminator: 0.542, loss Generator: 0.971
# Epoch [12/50] Batch 900/1563                       Loss Discriminator: 0.519, loss Generator: 1.192
# Epoch [12/50] Batch 1000/1563                       Loss Discriminator: 0.445, loss Generator: 1.149
# Epoch [12/50] Batch 1100/1563                       Loss Discriminator: 0.590, loss Generator: 1.227
# Epoch [12/50] Batch 1200/1563                       Loss Discriminator: 0.577, loss Generator: 1.121
# Epoch [12/50] Batch 1300/1563                       Loss Discriminator: 0.596, loss Generator: 0.981
# Epoch [12/50] Batch 1400/1563                       Loss Discriminator: 0.637, loss Generator: 0.963
# Epoch [12/50] Batch 1500/1563                       Loss Discriminator: 0.400, loss Generator: 0.980
# Fretchet Distance:  250.59499009981926
# Epoch [13/50] Batch 0/1563                       Loss Discriminator: 0.535, loss Generator: 1.181
# Epoch [13/50] Batch 100/1563                       Loss Discriminator: 0.374, loss Generator: 1.359
# Epoch [13/50] Batch 200/1563                       Loss Discriminator: 0.639, loss Generator: 0.979
# Epoch [13/50] Batch 300/1563                       Loss Discriminator: 0.470, loss Generator: 1.440
# Epoch [13/50] Batch 400/1563                       Loss Discriminator: 0.589, loss Generator: 0.955
# Epoch [13/50] Batch 500/1563                       Loss Discriminator: 0.523, loss Generator: 0.943
# Epoch [13/50] Batch 600/1563                       Loss Discriminator: 0.502, loss Generator: 0.976
# Epoch [13/50] Batch 700/1563                       Loss Discriminator: 0.654, loss Generator: 1.404
# Epoch [13/50] Batch 800/1563                       Loss Discriminator: 0.709, loss Generator: 0.864
# Epoch [13/50] Batch 900/1563                       Loss Discriminator: 0.427, loss Generator: 1.542
# Epoch [13/50] Batch 1000/1563                       Loss Discriminator: 0.527, loss Generator: 1.219
# Epoch [13/50] Batch 1100/1563                       Loss Discriminator: 0.500, loss Generator: 1.008
# Epoch [13/50] Batch 1200/1563                       Loss Discriminator: 0.554, loss Generator: 0.993
# Epoch [13/50] Batch 1300/1563                       Loss Discriminator: 0.474, loss Generator: 1.640
# Epoch [13/50] Batch 1400/1563                       Loss Discriminator: 0.500, loss Generator: 1.329
# Epoch [13/50] Batch 1500/1563                       Loss Discriminator: 0.643, loss Generator: 0.963
# Fretchet Distance:  263.99919306112895
# Epoch [14/50] Batch 0/1563                       Loss Discriminator: 0.510, loss Generator: 1.346
# Epoch [14/50] Batch 100/1563                       Loss Discriminator: 0.518, loss Generator: 1.118
# Epoch [14/50] Batch 200/1563                       Loss Discriminator: 0.489, loss Generator: 1.086
# Epoch [14/50] Batch 300/1563                       Loss Discriminator: 0.513, loss Generator: 1.336
# Epoch [14/50] Batch 400/1563                       Loss Discriminator: 0.459, loss Generator: 1.332
# Epoch [14/50] Batch 500/1563                       Loss Discriminator: 0.530, loss Generator: 1.050
# Epoch [14/50] Batch 600/1563                       Loss Discriminator: 0.502, loss Generator: 0.926
# Epoch [14/50] Batch 700/1563                       Loss Discriminator: 0.655, loss Generator: 0.587
# Epoch [14/50] Batch 800/1563                       Loss Discriminator: 0.547, loss Generator: 1.064
# Epoch [14/50] Batch 900/1563                       Loss Discriminator: 0.534, loss Generator: 1.414
# Epoch [14/50] Batch 1000/1563                       Loss Discriminator: 0.517, loss Generator: 1.432
# Epoch [14/50] Batch 1100/1563                       Loss Discriminator: 0.551, loss Generator: 1.236
# Epoch [14/50] Batch 1200/1563                       Loss Discriminator: 0.545, loss Generator: 1.005
# Epoch [14/50] Batch 1300/1563                       Loss Discriminator: 0.534, loss Generator: 1.118
# Epoch [14/50] Batch 1400/1563                       Loss Discriminator: 0.518, loss Generator: 1.197
# Epoch [14/50] Batch 1500/1563                       Loss Discriminator: 0.590, loss Generator: 1.156
# Fretchet Distance:  256.32317464471225
# Epoch [15/50] Batch 0/1563                       Loss Discriminator: 0.520, loss Generator: 1.404
# Epoch [15/50] Batch 100/1563                       Loss Discriminator: 0.488, loss Generator: 1.329
# Epoch [15/50] Batch 200/1563                       Loss Discriminator: 0.451, loss Generator: 1.359
# Epoch [15/50] Batch 300/1563                       Loss Discriminator: 0.475, loss Generator: 1.335
# Epoch [15/50] Batch 400/1563                       Loss Discriminator: 0.478, loss Generator: 1.816
# Epoch [15/50] Batch 500/1563                       Loss Discriminator: 0.489, loss Generator: 0.845
# Epoch [15/50] Batch 600/1563                       Loss Discriminator: 0.464, loss Generator: 1.301
# Epoch [15/50] Batch 700/1563                       Loss Discriminator: 0.512, loss Generator: 1.173
# Epoch [15/50] Batch 800/1563                       Loss Discriminator: 0.534, loss Generator: 1.278
# Epoch [15/50] Batch 900/1563                       Loss Discriminator: 0.451, loss Generator: 1.122
# Epoch [15/50] Batch 1000/1563                       Loss Discriminator: 0.495, loss Generator: 1.249
# Epoch [15/50] Batch 1100/1563                       Loss Discriminator: 0.490, loss Generator: 1.696
# Epoch [15/50] Batch 1200/1563                       Loss Discriminator: 0.402, loss Generator: 1.820
# Epoch [15/50] Batch 1300/1563                       Loss Discriminator: 0.549, loss Generator: 1.405
# Epoch [15/50] Batch 1400/1563                       Loss Discriminator: 0.466, loss Generator: 1.337
# Epoch [15/50] Batch 1500/1563                       Loss Discriminator: 0.575, loss Generator: 1.046
# Fretchet Distance:  259.68557619559
# Epoch [16/50] Batch 0/1563                       Loss Discriminator: 0.860, loss Generator: 2.017
# Epoch [16/50] Batch 100/1563                       Loss Discriminator: 0.494, loss Generator: 1.237
# Epoch [16/50] Batch 200/1563                       Loss Discriminator: 0.439, loss Generator: 1.105
# Epoch [16/50] Batch 300/1563                       Loss Discriminator: 0.504, loss Generator: 1.726
# Epoch [16/50] Batch 400/1563                       Loss Discriminator: 0.375, loss Generator: 1.532
# Epoch [16/50] Batch 500/1563                       Loss Discriminator: 0.382, loss Generator: 1.721
# Epoch [16/50] Batch 600/1563                       Loss Discriminator: 0.524, loss Generator: 1.062
# Epoch [16/50] Batch 700/1563                       Loss Discriminator: 0.448, loss Generator: 1.448
# Epoch [16/50] Batch 800/1563                       Loss Discriminator: 0.402, loss Generator: 1.403
# Epoch [16/50] Batch 900/1563                       Loss Discriminator: 0.486, loss Generator: 1.329
# Epoch [16/50] Batch 1000/1563                       Loss Discriminator: 0.420, loss Generator: 1.425
# Epoch [16/50] Batch 1100/1563                       Loss Discriminator: 0.412, loss Generator: 1.504
# Epoch [16/50] Batch 1200/1563                       Loss Discriminator: 0.586, loss Generator: 1.068
# Epoch [16/50] Batch 1300/1563                       Loss Discriminator: 0.457, loss Generator: 1.320
# Epoch [16/50] Batch 1400/1563                       Loss Discriminator: 0.477, loss Generator: 1.020
# Epoch [16/50] Batch 1500/1563                       Loss Discriminator: 0.408, loss Generator: 1.474
# Fretchet Distance:  244.72501231769036
# Epoch [17/50] Batch 0/1563                       Loss Discriminator: 0.577, loss Generator: 0.804
# Epoch [17/50] Batch 100/1563                       Loss Discriminator: 0.433, loss Generator: 1.529
# Epoch [17/50] Batch 200/1563                       Loss Discriminator: 0.578, loss Generator: 1.336
# Epoch [17/50] Batch 300/1563                       Loss Discriminator: 0.677, loss Generator: 1.022
# Epoch [17/50] Batch 400/1563                       Loss Discriminator: 0.608, loss Generator: 2.380
# Epoch [17/50] Batch 500/1563                       Loss Discriminator: 0.616, loss Generator: 1.012
# Epoch [17/50] Batch 600/1563                       Loss Discriminator: 0.417, loss Generator: 1.197
# Epoch [17/50] Batch 700/1563                       Loss Discriminator: 0.429, loss Generator: 1.601
# Epoch [17/50] Batch 800/1563                       Loss Discriminator: 0.453, loss Generator: 1.212
# Epoch [17/50] Batch 900/1563                       Loss Discriminator: 0.511, loss Generator: 2.110
# Epoch [17/50] Batch 1000/1563                       Loss Discriminator: 0.461, loss Generator: 1.346
# Epoch [17/50] Batch 1100/1563                       Loss Discriminator: 0.623, loss Generator: 1.311
# Epoch [17/50] Batch 1200/1563                       Loss Discriminator: 0.628, loss Generator: 1.023
# Epoch [17/50] Batch 1300/1563                       Loss Discriminator: 0.406, loss Generator: 1.258
# Epoch [17/50] Batch 1400/1563                       Loss Discriminator: 0.559, loss Generator: 1.093
# Epoch [17/50] Batch 1500/1563                       Loss Discriminator: 0.501, loss Generator: 1.444
# Fretchet Distance:  267.66119263802636
# Epoch [18/50] Batch 0/1563                       Loss Discriminator: 0.462, loss Generator: 1.501
# Epoch [18/50] Batch 100/1563                       Loss Discriminator: 0.341, loss Generator: 1.616
# Epoch [18/50] Batch 200/1563                       Loss Discriminator: 0.459, loss Generator: 1.375
# Epoch [18/50] Batch 300/1563                       Loss Discriminator: 0.589, loss Generator: 0.947
# Epoch [18/50] Batch 400/1563                       Loss Discriminator: 0.376, loss Generator: 1.605
# Epoch [18/50] Batch 500/1563                       Loss Discriminator: 0.438, loss Generator: 1.749
# Epoch [18/50] Batch 600/1563                       Loss Discriminator: 0.413, loss Generator: 1.921
# Epoch [18/50] Batch 700/1563                       Loss Discriminator: 0.515, loss Generator: 1.193
# Epoch [18/50] Batch 800/1563                       Loss Discriminator: 0.390, loss Generator: 1.314
# Epoch [18/50] Batch 900/1563                       Loss Discriminator: 0.363, loss Generator: 1.412
# Epoch [18/50] Batch 1000/1563                       Loss Discriminator: 0.405, loss Generator: 1.872
# Epoch [18/50] Batch 1100/1563                       Loss Discriminator: 0.497, loss Generator: 1.131
# Epoch [18/50] Batch 1200/1563                       Loss Discriminator: 0.336, loss Generator: 1.526
# Epoch [18/50] Batch 1300/1563                       Loss Discriminator: 0.358, loss Generator: 1.588
# Epoch [18/50] Batch 1400/1563                       Loss Discriminator: 0.407, loss Generator: 1.392
# Epoch [18/50] Batch 1500/1563                       Loss Discriminator: 0.480, loss Generator: 1.551
# Fretchet Distance:  264.05374932600813
# Epoch [19/50] Batch 0/1563                       Loss Discriminator: 0.447, loss Generator: 1.426
# Epoch [19/50] Batch 100/1563                       Loss Discriminator: 0.428, loss Generator: 1.872
# Epoch [19/50] Batch 200/1563                       Loss Discriminator: 0.449, loss Generator: 1.465
# Epoch [19/50] Batch 300/1563                       Loss Discriminator: 0.435, loss Generator: 1.372
# Epoch [19/50] Batch 400/1563                       Loss Discriminator: 0.622, loss Generator: 1.126
# Epoch [19/50] Batch 500/1563                       Loss Discriminator: 0.459, loss Generator: 1.333
# Epoch [19/50] Batch 600/1563                       Loss Discriminator: 0.409, loss Generator: 1.518
# Epoch [19/50] Batch 700/1563                       Loss Discriminator: 0.379, loss Generator: 1.949
# Epoch [19/50] Batch 800/1563                       Loss Discriminator: 0.394, loss Generator: 1.986
# Epoch [19/50] Batch 900/1563                       Loss Discriminator: 0.532, loss Generator: 1.560
# Epoch [19/50] Batch 1000/1563                       Loss Discriminator: 0.440, loss Generator: 1.330
# Epoch [19/50] Batch 1100/1563                       Loss Discriminator: 0.463, loss Generator: 1.289
# Epoch [19/50] Batch 1200/1563                       Loss Discriminator: 0.484, loss Generator: 1.311
# Epoch [19/50] Batch 1300/1563                       Loss Discriminator: 0.439, loss Generator: 1.551
# Epoch [19/50] Batch 1400/1563                       Loss Discriminator: 0.517, loss Generator: 1.801
# Epoch [19/50] Batch 1500/1563                       Loss Discriminator: 0.452, loss Generator: 1.454
# Fretchet Distance:  271.8633887533075
# Epoch [20/50] Batch 0/1563                       Loss Discriminator: 0.282, loss Generator: 2.252
# Epoch [20/50] Batch 100/1563                       Loss Discriminator: 0.394, loss Generator: 1.618
# Epoch [20/50] Batch 200/1563                       Loss Discriminator: 0.442, loss Generator: 1.485
# Epoch [20/50] Batch 300/1563                       Loss Discriminator: 0.376, loss Generator: 1.779
# Epoch [20/50] Batch 400/1563                       Loss Discriminator: 0.484, loss Generator: 1.413
# Epoch [20/50] Batch 500/1563                       Loss Discriminator: 0.474, loss Generator: 1.408
# Epoch [20/50] Batch 600/1563                       Loss Discriminator: 0.430, loss Generator: 1.593
# Epoch [20/50] Batch 700/1563                       Loss Discriminator: 0.492, loss Generator: 1.816
# Epoch [20/50] Batch 800/1563                       Loss Discriminator: 0.378, loss Generator: 1.591
# Epoch [20/50] Batch 900/1563                       Loss Discriminator: 0.350, loss Generator: 1.379
# Epoch [20/50] Batch 1000/1563                       Loss Discriminator: 0.569, loss Generator: 1.581
# Epoch [20/50] Batch 1100/1563                       Loss Discriminator: 0.569, loss Generator: 1.309
# Epoch [20/50] Batch 1200/1563                       Loss Discriminator: 0.626, loss Generator: 1.580
# Epoch [20/50] Batch 1300/1563                       Loss Discriminator: 0.478, loss Generator: 1.411
# Epoch [20/50] Batch 1400/1563                       Loss Discriminator: 0.521, loss Generator: 1.249
# Epoch [20/50] Batch 1500/1563                       Loss Discriminator: 0.434, loss Generator: 1.233
# Fretchet Distance:  258.37999968590304
# Epoch [21/50] Batch 0/1563                       Loss Discriminator: 0.364, loss Generator: 1.584
# Epoch [21/50] Batch 100/1563                       Loss Discriminator: 0.321, loss Generator: 1.509
# Epoch [21/50] Batch 200/1563                       Loss Discriminator: 0.529, loss Generator: 2.523
# Epoch [21/50] Batch 300/1563                       Loss Discriminator: 0.467, loss Generator: 1.915
# Epoch [21/50] Batch 400/1563                       Loss Discriminator: 0.471, loss Generator: 1.569
# Epoch [21/50] Batch 500/1563                       Loss Discriminator: 0.452, loss Generator: 1.299
# Epoch [21/50] Batch 600/1563                       Loss Discriminator: 0.548, loss Generator: 1.525
# Epoch [21/50] Batch 700/1563                       Loss Discriminator: 0.472, loss Generator: 1.194
# Epoch [21/50] Batch 800/1563                       Loss Discriminator: 0.601, loss Generator: 1.238
# Epoch [21/50] Batch 900/1563                       Loss Discriminator: 0.435, loss Generator: 1.263
# Epoch [21/50] Batch 1000/1563                       Loss Discriminator: 0.459, loss Generator: 1.714
# Epoch [21/50] Batch 1100/1563                       Loss Discriminator: 0.373, loss Generator: 1.523
# Epoch [21/50] Batch 1200/1563                       Loss Discriminator: 0.383, loss Generator: 1.719
# Epoch [21/50] Batch 1300/1563                       Loss Discriminator: 0.407, loss Generator: 1.634
# Epoch [21/50] Batch 1400/1563                       Loss Discriminator: 0.331, loss Generator: 1.905
# Epoch [21/50] Batch 1500/1563                       Loss Discriminator: 0.379, loss Generator: 1.335
# Fretchet Distance:  274.0187076865891
# Epoch [22/50] Batch 0/1563                       Loss Discriminator: 0.561, loss Generator: 1.681
# Epoch [22/50] Batch 100/1563                       Loss Discriminator: 0.473, loss Generator: 1.704
# Epoch [22/50] Batch 200/1563                       Loss Discriminator: 0.401, loss Generator: 1.651
# Epoch [22/50] Batch 300/1563                       Loss Discriminator: 0.472, loss Generator: 1.521
# Epoch [22/50] Batch 400/1563                       Loss Discriminator: 0.457, loss Generator: 1.421
# Epoch [22/50] Batch 500/1563                       Loss Discriminator: 0.354, loss Generator: 1.918
# Epoch [22/50] Batch 600/1563                       Loss Discriminator: 0.503, loss Generator: 2.392
# Epoch [22/50] Batch 700/1563                       Loss Discriminator: 0.550, loss Generator: 1.190
# Epoch [22/50] Batch 800/1563                       Loss Discriminator: 0.493, loss Generator: 1.357
# Epoch [22/50] Batch 900/1563                       Loss Discriminator: 0.333, loss Generator: 1.755
# Epoch [22/50] Batch 1000/1563                       Loss Discriminator: 0.422, loss Generator: 1.997
# Epoch [22/50] Batch 1100/1563                       Loss Discriminator: 0.390, loss Generator: 1.749
# Epoch [22/50] Batch 1200/1563                       Loss Discriminator: 0.452, loss Generator: 1.567
# Epoch [22/50] Batch 1300/1563                       Loss Discriminator: 0.309, loss Generator: 2.036
# Epoch [22/50] Batch 1400/1563                       Loss Discriminator: 0.373, loss Generator: 1.761
# Epoch [22/50] Batch 1500/1563                       Loss Discriminator: 0.371, loss Generator: 1.580
# Fretchet Distance:  291.7019370815844
# Epoch [23/50] Batch 0/1563                       Loss Discriminator: 0.503, loss Generator: 1.404
# Epoch [23/50] Batch 100/1563                       Loss Discriminator: 0.514, loss Generator: 1.627
# Epoch [23/50] Batch 200/1563                       Loss Discriminator: 0.374, loss Generator: 1.679
# Epoch [23/50] Batch 300/1563                       Loss Discriminator: 0.527, loss Generator: 1.334
# Epoch [23/50] Batch 400/1563                       Loss Discriminator: 0.439, loss Generator: 1.982
# Epoch [23/50] Batch 500/1563                       Loss Discriminator: 0.373, loss Generator: 1.644
# Epoch [23/50] Batch 600/1563                       Loss Discriminator: 0.402, loss Generator: 1.495
# Epoch [23/50] Batch 700/1563                       Loss Discriminator: 0.452, loss Generator: 1.430
# Epoch [23/50] Batch 800/1563                       Loss Discriminator: 0.384, loss Generator: 1.475
# Epoch [23/50] Batch 900/1563                       Loss Discriminator: 0.363, loss Generator: 1.995
# Epoch [23/50] Batch 1000/1563                       Loss Discriminator: 0.427, loss Generator: 1.581
# Epoch [23/50] Batch 1100/1563                       Loss Discriminator: 0.348, loss Generator: 1.649
# Epoch [23/50] Batch 1200/1563                       Loss Discriminator: 0.334, loss Generator: 1.542
# Epoch [23/50] Batch 1300/1563                       Loss Discriminator: 0.424, loss Generator: 2.053
# Epoch [23/50] Batch 1400/1563                       Loss Discriminator: 0.389, loss Generator: 1.447
# Epoch [23/50] Batch 1500/1563                       Loss Discriminator: 0.356, loss Generator: 1.555
# Fretchet Distance:  257.7230566608225
# Epoch [24/50] Batch 0/1563                       Loss Discriminator: 0.421, loss Generator: 1.709
# Epoch [24/50] Batch 100/1563                       Loss Discriminator: 0.432, loss Generator: 1.461
# Epoch [24/50] Batch 200/1563                       Loss Discriminator: 0.392, loss Generator: 1.453
# Epoch [24/50] Batch 300/1563                       Loss Discriminator: 0.358, loss Generator: 1.917
# Epoch [24/50] Batch 400/1563                       Loss Discriminator: 0.330, loss Generator: 1.790
# Epoch [24/50] Batch 500/1563                       Loss Discriminator: 0.420, loss Generator: 1.395
# Epoch [24/50] Batch 600/1563                       Loss Discriminator: 0.432, loss Generator: 1.610
# Epoch [24/50] Batch 700/1563                       Loss Discriminator: 0.401, loss Generator: 1.921
# Epoch [24/50] Batch 800/1563                       Loss Discriminator: 0.472, loss Generator: 2.011
# Epoch [24/50] Batch 900/1563                       Loss Discriminator: 0.328, loss Generator: 1.973
# Epoch [24/50] Batch 1000/1563                       Loss Discriminator: 0.349, loss Generator: 2.221
# Epoch [24/50] Batch 1100/1563                       Loss Discriminator: 0.375, loss Generator: 1.246
# Epoch [24/50] Batch 1200/1563                       Loss Discriminator: 0.495, loss Generator: 1.780
# Epoch [24/50] Batch 1300/1563                       Loss Discriminator: 0.531, loss Generator: 1.251
# Epoch [24/50] Batch 1400/1563                       Loss Discriminator: 0.398, loss Generator: 1.510
# Epoch [24/50] Batch 1500/1563                       Loss Discriminator: 0.535, loss Generator: 1.370
# Fretchet Distance:  241.59724649377017
# Epoch [25/50] Batch 0/1563                       Loss Discriminator: 0.387, loss Generator: 1.816
# Epoch [25/50] Batch 100/1563                       Loss Discriminator: 0.444, loss Generator: 1.491
# Epoch [25/50] Batch 200/1563                       Loss Discriminator: 0.353, loss Generator: 1.464
# Epoch [25/50] Batch 300/1563                       Loss Discriminator: 0.429, loss Generator: 1.355
# Epoch [25/50] Batch 400/1563                       Loss Discriminator: 0.315, loss Generator: 2.006
# Epoch [25/50] Batch 500/1563                       Loss Discriminator: 0.399, loss Generator: 2.044
# Epoch [25/50] Batch 600/1563                       Loss Discriminator: 0.497, loss Generator: 1.969
# Epoch [25/50] Batch 700/1563                       Loss Discriminator: 0.333, loss Generator: 2.071
# Epoch [25/50] Batch 800/1563                       Loss Discriminator: 0.385, loss Generator: 1.805
# Epoch [25/50] Batch 900/1563                       Loss Discriminator: 0.416, loss Generator: 1.934
# Epoch [25/50] Batch 1000/1563                       Loss Discriminator: 0.398, loss Generator: 1.529
# Epoch [25/50] Batch 1100/1563                       Loss Discriminator: 0.361, loss Generator: 1.648
# Epoch [25/50] Batch 1200/1563                       Loss Discriminator: 0.275, loss Generator: 1.948
# Epoch [25/50] Batch 1300/1563                       Loss Discriminator: 0.403, loss Generator: 1.501
# Epoch [25/50] Batch 1400/1563                       Loss Discriminator: 0.341, loss Generator: 2.000
# Epoch [25/50] Batch 1500/1563                       Loss Discriminator: 0.310, loss Generator: 2.236
# Fretchet Distance:  259.55018169501295
# Epoch [26/50] Batch 0/1563                       Loss Discriminator: 0.517, loss Generator: 1.654
# Epoch [26/50] Batch 100/1563                       Loss Discriminator: 0.289, loss Generator: 1.666
# Epoch [26/50] Batch 200/1563                       Loss Discriminator: 0.413, loss Generator: 1.642
# Epoch [26/50] Batch 300/1563                       Loss Discriminator: 0.366, loss Generator: 2.160
# Epoch [26/50] Batch 400/1563                       Loss Discriminator: 0.356, loss Generator: 1.684
# Epoch [26/50] Batch 500/1563                       Loss Discriminator: 0.396, loss Generator: 1.539
# Epoch [26/50] Batch 600/1563                       Loss Discriminator: 0.393, loss Generator: 1.840
# Epoch [26/50] Batch 700/1563                       Loss Discriminator: 0.399, loss Generator: 1.454
# Epoch [26/50] Batch 800/1563                       Loss Discriminator: 0.291, loss Generator: 2.092
# Epoch [26/50] Batch 900/1563                       Loss Discriminator: 0.311, loss Generator: 2.092
# Epoch [26/50] Batch 1000/1563                       Loss Discriminator: 0.287, loss Generator: 1.966
# Epoch [26/50] Batch 1100/1563                       Loss Discriminator: 0.390, loss Generator: 1.986
# Epoch [26/50] Batch 1200/1563                       Loss Discriminator: 0.297, loss Generator: 1.819
# Epoch [26/50] Batch 1300/1563                       Loss Discriminator: 0.325, loss Generator: 1.930
# Epoch [26/50] Batch 1400/1563                       Loss Discriminator: 0.285, loss Generator: 2.039
# Epoch [26/50] Batch 1500/1563                       Loss Discriminator: 0.433, loss Generator: 1.763
# Fretchet Distance:  280.33920541449095
# Epoch [27/50] Batch 0/1563                       Loss Discriminator: 0.294, loss Generator: 2.241
# Epoch [27/50] Batch 100/1563                       Loss Discriminator: 0.367, loss Generator: 2.552
# Epoch [27/50] Batch 200/1563                       Loss Discriminator: 0.557, loss Generator: 1.417
# Epoch [27/50] Batch 300/1563                       Loss Discriminator: 0.467, loss Generator: 1.629
# Epoch [27/50] Batch 400/1563                       Loss Discriminator: 0.261, loss Generator: 2.125
# Epoch [27/50] Batch 500/1563                       Loss Discriminator: 0.285, loss Generator: 1.863
# Epoch [27/50] Batch 600/1563                       Loss Discriminator: 0.330, loss Generator: 1.541
# Epoch [27/50] Batch 700/1563                       Loss Discriminator: 0.327, loss Generator: 1.800
# Epoch [27/50] Batch 800/1563                       Loss Discriminator: 0.318, loss Generator: 1.896
# Epoch [27/50] Batch 900/1563                       Loss Discriminator: 0.304, loss Generator: 1.896
# Epoch [27/50] Batch 1000/1563                       Loss Discriminator: 0.311, loss Generator: 1.780
# Epoch [27/50] Batch 1100/1563                       Loss Discriminator: 0.373, loss Generator: 2.076
# Epoch [27/50] Batch 1200/1563                       Loss Discriminator: 0.336, loss Generator: 1.881
# Epoch [27/50] Batch 1300/1563                       Loss Discriminator: 0.297, loss Generator: 1.684
# Epoch [27/50] Batch 1400/1563                       Loss Discriminator: 0.400, loss Generator: 2.029
# Epoch [27/50] Batch 1500/1563                       Loss Discriminator: 0.367, loss Generator: 1.531
# Fretchet Distance:  250.10490363611083
# Epoch [28/50] Batch 0/1563                       Loss Discriminator: 0.420, loss Generator: 2.504
# Epoch [28/50] Batch 100/1563                       Loss Discriminator: 0.234, loss Generator: 2.296
# Epoch [28/50] Batch 200/1563                       Loss Discriminator: 0.495, loss Generator: 1.753
# Epoch [28/50] Batch 300/1563                       Loss Discriminator: 0.346, loss Generator: 1.794
# Epoch [28/50] Batch 400/1563                       Loss Discriminator: 0.364, loss Generator: 1.826
# Epoch [28/50] Batch 500/1563                       Loss Discriminator: 0.309, loss Generator: 2.131
# Epoch [28/50] Batch 600/1563                       Loss Discriminator: 0.366, loss Generator: 2.109
# Epoch [28/50] Batch 700/1563                       Loss Discriminator: 0.350, loss Generator: 1.584
# Epoch [28/50] Batch 800/1563                       Loss Discriminator: 0.361, loss Generator: 1.837
# Epoch [28/50] Batch 900/1563                       Loss Discriminator: 0.306, loss Generator: 1.690
# Epoch [28/50] Batch 1000/1563                       Loss Discriminator: 0.392, loss Generator: 1.558
# Epoch [28/50] Batch 1100/1563                       Loss Discriminator: 0.207, loss Generator: 2.230
# Epoch [28/50] Batch 1200/1563                       Loss Discriminator: 0.390, loss Generator: 2.319
# Epoch [28/50] Batch 1300/1563                       Loss Discriminator: 0.271, loss Generator: 2.307
# Epoch [28/50] Batch 1400/1563                       Loss Discriminator: 0.308, loss Generator: 1.808
# Epoch [28/50] Batch 1500/1563                       Loss Discriminator: 0.380, loss Generator: 1.616
# Fretchet Distance:  256.42102183076906
# Epoch [29/50] Batch 0/1563                       Loss Discriminator: 0.290, loss Generator: 2.572
# Epoch [29/50] Batch 100/1563                       Loss Discriminator: 0.317, loss Generator: 2.343
# Epoch [29/50] Batch 200/1563                       Loss Discriminator: 0.314, loss Generator: 1.740
# Epoch [29/50] Batch 300/1563                       Loss Discriminator: 0.451, loss Generator: 1.679
# Epoch [29/50] Batch 400/1563                       Loss Discriminator: 0.364, loss Generator: 1.845
# Epoch [29/50] Batch 500/1563                       Loss Discriminator: 0.275, loss Generator: 2.265
# Epoch [29/50] Batch 600/1563                       Loss Discriminator: 0.256, loss Generator: 2.491
# Epoch [29/50] Batch 700/1563                       Loss Discriminator: 0.323, loss Generator: 2.431
# Epoch [29/50] Batch 800/1563                       Loss Discriminator: 0.381, loss Generator: 1.684
# Epoch [29/50] Batch 900/1563                       Loss Discriminator: 0.312, loss Generator: 2.046
# Epoch [29/50] Batch 1000/1563                       Loss Discriminator: 0.265, loss Generator: 2.278
# Epoch [29/50] Batch 1100/1563                       Loss Discriminator: 0.377, loss Generator: 1.987
# Epoch [29/50] Batch 1200/1563                       Loss Discriminator: 0.315, loss Generator: 1.533
# Epoch [29/50] Batch 1300/1563                       Loss Discriminator: 0.536, loss Generator: 1.530
# Epoch [29/50] Batch 1400/1563                       Loss Discriminator: 0.314, loss Generator: 2.309
# Epoch [29/50] Batch 1500/1563                       Loss Discriminator: 0.350, loss Generator: 1.749
# Fretchet Distance:  275.075257891628
# Epoch [30/50] Batch 0/1563                       Loss Discriminator: 0.376, loss Generator: 1.997
# Epoch [30/50] Batch 100/1563                       Loss Discriminator: 0.263, loss Generator: 2.379
# Epoch [30/50] Batch 200/1563                       Loss Discriminator: 0.362, loss Generator: 1.887
# Epoch [30/50] Batch 300/1563                       Loss Discriminator: 0.273, loss Generator: 2.162
# ...
# Epoch [41/50] Batch 500/1563                       Loss Discriminator: 0.137, loss Generator: 4.099
# Epoch [41/50] Batch 600/1563                       Loss Discriminator: 0.123, loss Generator: 3.570
# Epoch [41/50] Batch 700/1563                       Loss Discriminator: 0.153, loss Generator: 2.995
# Epoch [41/50] Batch 800/1563                       Loss Discriminator: 0.145, loss Generator: 3.705
# Epoch [41/50] Batch 900/1563                       Loss Discriminator: 0.316, loss Generator: 2.322
# Epoch [41/50] Batch 1000/1563                       Loss Discriminator: 0.229, loss Generator: 2.328
# Epoch [41/50] Batch 1100/1563                       Loss Discriminator: 0.239, loss Generator: 2.516
# Epoch [41/50] Batch 1200/1563                       Loss Discriminator: 0.234, loss Generator: 2.914
# Epoch [41/50] Batch 1300/1563                       Loss Discriminator: 0.150, loss Generator: 3.613
# Epoch [41/50] Batch 1400/1563                       Loss Discriminator: 0.200, loss Generator: 2.676
# Epoch [41/50] Batch 1500/1563                       Loss Discriminator: 0.168, loss Generator: 3.437
# Fretchet Distance:  272.67744026128275
# Epoch [42/50] Batch 0/1563                       Loss Discriminator: 0.202, loss Generator: 3.819
# Epoch [42/50] Batch 100/1563                       Loss Discriminator: 0.181, loss Generator: 3.262
# Epoch [42/50] Batch 200/1563                       Loss Discriminator: 0.159, loss Generator: 3.065
# Epoch [42/50] Batch 300/1563                       Loss Discriminator: 0.097, loss Generator: 3.855
# Epoch [42/50] Batch 400/1563                       Loss Discriminator: 0.144, loss Generator: 3.406
# Epoch [42/50] Batch 500/1563                       Loss Discriminator: 0.229, loss Generator: 3.753
# Epoch [42/50] Batch 600/1563                       Loss Discriminator: 0.265, loss Generator: 3.069
# Epoch [42/50] Batch 700/1563                       Loss Discriminator: 0.208, loss Generator: 3.087
# Epoch [42/50] Batch 800/1563                       Loss Discriminator: 0.158, loss Generator: 3.100
# Epoch [42/50] Batch 900/1563                       Loss Discriminator: 0.289, loss Generator: 3.142
# Epoch [42/50] Batch 1000/1563                       Loss Discriminator: 0.201, loss Generator: 3.290
# Epoch [42/50] Batch 1100/1563                       Loss Discriminator: 0.239, loss Generator: 3.309
# Epoch [42/50] Batch 1200/1563                       Loss Discriminator: 0.185, loss Generator: 3.267
# Epoch [42/50] Batch 1300/1563                       Loss Discriminator: 0.262, loss Generator: 3.254
# Epoch [42/50] Batch 1400/1563                       Loss Discriminator: 0.277, loss Generator: 3.177
# Epoch [42/50] Batch 1500/1563                       Loss Discriminator: 0.166, loss Generator: 3.978
# Fretchet Distance:  249.4496191975214
# Epoch [43/50] Batch 0/1563                       Loss Discriminator: 0.156, loss Generator: 3.230
# Epoch [43/50] Batch 100/1563                       Loss Discriminator: 0.157, loss Generator: 3.756
# Epoch [43/50] Batch 200/1563                       Loss Discriminator: 0.184, loss Generator: 3.563
# Epoch [43/50] Batch 300/1563                       Loss Discriminator: 0.160, loss Generator: 3.845
# Epoch [43/50] Batch 400/1563                       Loss Discriminator: 0.156, loss Generator: 2.906
# Epoch [43/50] Batch 500/1563                       Loss Discriminator: 0.194, loss Generator: 3.620
# Epoch [43/50] Batch 600/1563                       Loss Discriminator: 0.108, loss Generator: 3.605
# Epoch [43/50] Batch 700/1563                       Loss Discriminator: 0.224, loss Generator: 3.491
# Epoch [43/50] Batch 800/1563                       Loss Discriminator: 0.247, loss Generator: 3.381
# Epoch [43/50] Batch 900/1563                       Loss Discriminator: 0.208, loss Generator: 3.231
# Epoch [43/50] Batch 1000/1563                       Loss Discriminator: 0.380, loss Generator: 2.956
# Epoch [43/50] Batch 1100/1563                       Loss Discriminator: 0.166, loss Generator: 3.261
# Epoch [43/50] Batch 1200/1563                       Loss Discriminator: 0.157, loss Generator: 3.285
# Epoch [43/50] Batch 1300/1563                       Loss Discriminator: 0.148, loss Generator: 4.079
# Epoch [43/50] Batch 1400/1563                       Loss Discriminator: 0.283, loss Generator: 2.411
# Epoch [43/50] Batch 1500/1563                       Loss Discriminator: 0.170, loss Generator: 2.861
# Fretchet Distance:  241.10281122809482
# Epoch [44/50] Batch 0/1563                       Loss Discriminator: 0.170, loss Generator: 3.362
# Epoch [44/50] Batch 100/1563                       Loss Discriminator: 0.172, loss Generator: 3.450
# Epoch [44/50] Batch 200/1563                       Loss Discriminator: 0.203, loss Generator: 3.352
# Epoch [44/50] Batch 300/1563                       Loss Discriminator: 0.151, loss Generator: 3.658
# Epoch [44/50] Batch 400/1563                       Loss Discriminator: 0.164, loss Generator: 3.382
# Epoch [44/50] Batch 500/1563                       Loss Discriminator: 0.125, loss Generator: 3.430
# Epoch [44/50] Batch 600/1563                       Loss Discriminator: 0.147, loss Generator: 4.454
# Epoch [44/50] Batch 700/1563                       Loss Discriminator: 0.125, loss Generator: 3.665
# Epoch [44/50] Batch 800/1563                       Loss Discriminator: 0.174, loss Generator: 2.992
# Epoch [44/50] Batch 900/1563                       Loss Discriminator: 0.208, loss Generator: 3.976
# Epoch [44/50] Batch 1000/1563                       Loss Discriminator: 0.230, loss Generator: 3.668
# Epoch [44/50] Batch 1100/1563                       Loss Discriminator: 0.201, loss Generator: 2.761
# Epoch [44/50] Batch 1200/1563                       Loss Discriminator: 0.178, loss Generator: 3.395
# Epoch [44/50] Batch 1300/1563                       Loss Discriminator: 0.128, loss Generator: 3.747
# Epoch [44/50] Batch 1400/1563                       Loss Discriminator: 0.150, loss Generator: 3.543
# Epoch [44/50] Batch 1500/1563                       Loss Discriminator: 0.156, loss Generator: 4.224
# Fretchet Distance:  274.2380068163624
# Epoch [45/50] Batch 0/1563                       Loss Discriminator: 0.185, loss Generator: 4.196
# Epoch [45/50] Batch 100/1563                       Loss Discriminator: 0.171, loss Generator: 3.884
# Epoch [45/50] Batch 200/1563                       Loss Discriminator: 0.200, loss Generator: 3.625
# Epoch [45/50] Batch 300/1563                       Loss Discriminator: 0.274, loss Generator: 3.059
# Epoch [45/50] Batch 400/1563                       Loss Discriminator: 0.176, loss Generator: 3.214
# Epoch [45/50] Batch 500/1563                       Loss Discriminator: 0.187, loss Generator: 3.610
# Epoch [45/50] Batch 600/1563                       Loss Discriminator: 0.301, loss Generator: 4.074
# Epoch [45/50] Batch 700/1563                       Loss Discriminator: 0.252, loss Generator: 2.952
# Epoch [45/50] Batch 800/1563                       Loss Discriminator: 0.201, loss Generator: 3.422
# Epoch [45/50] Batch 900/1563                       Loss Discriminator: 0.141, loss Generator: 3.371
# Epoch [45/50] Batch 1000/1563                       Loss Discriminator: 0.212, loss Generator: 3.444
# Epoch [45/50] Batch 1100/1563                       Loss Discriminator: 0.052, loss Generator: 4.119
# Epoch [45/50] Batch 1200/1563                       Loss Discriminator: 0.233, loss Generator: 3.223
# Epoch [45/50] Batch 1300/1563                       Loss Discriminator: 0.189, loss Generator: 4.169
# Epoch [45/50] Batch 1400/1563                       Loss Discriminator: 0.167, loss Generator: 3.301
# Epoch [45/50] Batch 1500/1563                       Loss Discriminator: 0.132, loss Generator: 3.926
# Fretchet Distance:  295.5920697961502
# Epoch [46/50] Batch 0/1563                       Loss Discriminator: 0.135, loss Generator: 4.029
# Epoch [46/50] Batch 100/1563                       Loss Discriminator: 0.113, loss Generator: 4.343
# Epoch [46/50] Batch 200/1563                       Loss Discriminator: 0.207, loss Generator: 3.855
# Epoch [46/50] Batch 300/1563                       Loss Discriminator: 0.143, loss Generator: 3.986
# Epoch [46/50] Batch 400/1563                       Loss Discriminator: 0.126, loss Generator: 3.735
# Epoch [46/50] Batch 500/1563                       Loss Discriminator: 0.228, loss Generator: 3.201
# Epoch [46/50] Batch 600/1563                       Loss Discriminator: 0.171, loss Generator: 4.175
# Epoch [46/50] Batch 700/1563                       Loss Discriminator: 0.191, loss Generator: 3.322
# Epoch [46/50] Batch 800/1563                       Loss Discriminator: 0.182, loss Generator: 3.508
# Epoch [46/50] Batch 900/1563                       Loss Discriminator: 0.157, loss Generator: 3.753
# Epoch [46/50] Batch 1000/1563                       Loss Discriminator: 0.220, loss Generator: 3.000
# Epoch [46/50] Batch 1100/1563                       Loss Discriminator: 0.098, loss Generator: 4.060
# Epoch [46/50] Batch 1200/1563                       Loss Discriminator: 0.269, loss Generator: 2.725
# Epoch [46/50] Batch 1300/1563                       Loss Discriminator: 0.175, loss Generator: 4.229
# Epoch [46/50] Batch 1400/1563                       Loss Discriminator: 0.147, loss Generator: 4.201
# Epoch [46/50] Batch 1500/1563                       Loss Discriminator: 0.359, loss Generator: 3.605
# Fretchet Distance:  280.1356519304993
# Epoch [47/50] Batch 0/1563                       Loss Discriminator: 0.261, loss Generator: 4.758
# Epoch [47/50] Batch 100/1563                       Loss Discriminator: 0.095, loss Generator: 3.820
# Epoch [47/50] Batch 200/1563                       Loss Discriminator: 0.136, loss Generator: 4.277
# Epoch [47/50] Batch 300/1563                       Loss Discriminator: 0.134, loss Generator: 3.923
# Epoch [47/50] Batch 400/1563                       Loss Discriminator: 0.209, loss Generator: 3.628
# Epoch [47/50] Batch 500/1563                       Loss Discriminator: 0.200, loss Generator: 4.592
# Epoch [47/50] Batch 600/1563                       Loss Discriminator: 0.203, loss Generator: 4.067
# Epoch [47/50] Batch 700/1563                       Loss Discriminator: 0.144, loss Generator: 4.094
# Epoch [47/50] Batch 800/1563                       Loss Discriminator: 0.172, loss Generator: 3.652
# Epoch [47/50] Batch 900/1563                       Loss Discriminator: 0.141, loss Generator: 4.921
# Epoch [47/50] Batch 1000/1563                       Loss Discriminator: 0.077, loss Generator: 4.424
# Epoch [47/50] Batch 1100/1563                       Loss Discriminator: 0.304, loss Generator: 3.546
# Epoch [47/50] Batch 1200/1563                       Loss Discriminator: 0.196, loss Generator: 4.181
# Epoch [47/50] Batch 1300/1563                       Loss Discriminator: 0.134, loss Generator: 4.023
# Epoch [47/50] Batch 1400/1563                       Loss Discriminator: 0.218, loss Generator: 3.454
# Epoch [47/50] Batch 1500/1563                       Loss Discriminator: 0.098, loss Generator: 4.849
# Fretchet Distance:  259.19168743546817
# Epoch [48/50] Batch 0/1563                       Loss Discriminator: 0.098, loss Generator: 4.021
# Epoch [48/50] Batch 100/1563                       Loss Discriminator: 0.139, loss Generator: 5.247
# Epoch [48/50] Batch 200/1563                       Loss Discriminator: 0.140, loss Generator: 3.937
# Epoch [48/50] Batch 300/1563                       Loss Discriminator: 0.167, loss Generator: 4.536
# Epoch [48/50] Batch 400/1563                       Loss Discriminator: 0.203, loss Generator: 3.791
# Epoch [48/50] Batch 500/1563                       Loss Discriminator: 0.136, loss Generator: 3.390
# Epoch [48/50] Batch 600/1563                       Loss Discriminator: 0.130, loss Generator: 3.543
# Epoch [48/50] Batch 700/1563                       Loss Discriminator: 0.208, loss Generator: 4.559
# Epoch [48/50] Batch 800/1563                       Loss Discriminator: 0.254, loss Generator: 3.892
# Epoch [48/50] Batch 900/1563                       Loss Discriminator: 0.060, loss Generator: 4.511
# Epoch [48/50] Batch 1000/1563                       Loss Discriminator: 0.235, loss Generator: 3.417
# Epoch [48/50] Batch 1100/1563                       Loss Discriminator: 0.342, loss Generator: 4.399
# Epoch [48/50] Batch 1200/1563                       Loss Discriminator: 0.203, loss Generator: 3.827
# Epoch [48/50] Batch 1300/1563                       Loss Discriminator: 0.154, loss Generator: 3.552
# Epoch [48/50] Batch 1400/1563                       Loss Discriminator: 0.135, loss Generator: 3.840
# Epoch [48/50] Batch 1500/1563                       Loss Discriminator: 0.169, loss Generator: 3.679
# Fretchet Distance:  260.96119781765765
# Epoch [49/50] Batch 0/1563                       Loss Discriminator: 0.109, loss Generator: 3.930
# Epoch [49/50] Batch 100/1563                       Loss Discriminator: 0.205, loss Generator: 3.808
# Epoch [49/50] Batch 200/1563                       Loss Discriminator: 0.139, loss Generator: 4.488
# Epoch [49/50] Batch 300/1563                       Loss Discriminator: 0.063, loss Generator: 4.538
# Epoch [49/50] Batch 400/1563                       Loss Discriminator: 0.209, loss Generator: 3.509
# Epoch [49/50] Batch 500/1563                       Loss Discriminator: 0.128, loss Generator: 3.667
# Epoch [49/50] Batch 600/1563                       Loss Discriminator: 0.076, loss Generator: 4.598
# Epoch [49/50] Batch 700/1563                       Loss Discriminator: 0.159, loss Generator: 4.596
# Epoch [49/50] Batch 800/1563                       Loss Discriminator: 0.194, loss Generator: 4.205
# Epoch [49/50] Batch 900/1563                       Loss Discriminator: 0.157, loss Generator: 3.518
# Epoch [49/50] Batch 1000/1563                       Loss Discriminator: 0.159, loss Generator: 3.165
# Epoch [49/50] Batch 1100/1563                       Loss Discriminator: 0.175, loss Generator: 3.961
# Epoch [49/50] Batch 1200/1563                       Loss Discriminator: 0.128, loss Generator: 3.618
# Epoch [49/50] Batch 1300/1563                       Loss Discriminator: 0.220, loss Generator: 3.835
# Epoch [49/50] Batch 1400/1563                       Loss Discriminator: 0.128, loss Generator: 4.118
# Epoch [49/50] Batch 1500/1563                       Loss Discriminator: 0.156, loss Generator: 4.252
# Fretchet Distance:  290.3510144133475
# Epoch [50/50] Batch 0/1563                       Loss Discriminator: 0.161, loss Generator: 2.986
# Epoch [50/50] Batch 100/1563                       Loss Discriminator: 0.126, loss Generator: 4.080
# Epoch [50/50] Batch 200/1563                       Loss Discriminator: 0.178, loss Generator: 3.941
# Epoch [50/50] Batch 300/1563                       Loss Discriminator: 0.120, loss Generator: 4.625
# Epoch [50/50] Batch 400/1563                       Loss Discriminator: 0.095, loss Generator: 4.051
# Epoch [50/50] Batch 500/1563                       Loss Discriminator: 0.094, loss Generator: 4.115
# Epoch [50/50] Batch 600/1563                       Loss Discriminator: 0.077, loss Generator: 4.284
# Epoch [50/50] Batch 700/1563                       Loss Discriminator: 0.153, loss Generator: 3.760
# Epoch [50/50] Batch 800/1563                       Loss Discriminator: 0.083, loss Generator: 4.450
# Epoch [50/50] Batch 900/1563                       Loss Discriminator: 0.140, loss Generator: 4.818
# Epoch [50/50] Batch 1000/1563                       Loss Discriminator: 0.198, loss Generator: 3.427
# Epoch [50/50] Batch 1100/1563                       Loss Discriminator: 0.095, loss Generator: 4.038
# Epoch [50/50] Batch 1200/1563                       Loss Discriminator: 0.057, loss Generator: 4.502
# Epoch [50/50] Batch 1300/1563                       Loss Discriminator: 0.090, loss Generator: 4.223
# Epoch [50/50] Batch 1400/1563                       Loss Discriminator: 0.236, loss Generator: 4.381
# Epoch [50/50] Batch 1500/1563                       Loss Discriminator: 0.087, loss Generator: 4.276
# Fretchet Distance:  278.7698404410896

# %%
for epoch in range(num_epochs):
    epoch = epoch+1

    for batch_idx, data in enumerate(dataloader,0):
        #training with real batch
        real = data[0].to(device)
        noise = torch.randn(128, 100, 1, 1).to(device)
        fake = gen(noise) #genrator img data

        images = gen(noise,sampleLabel).detach()
    utils.save_image(images.detach(),'Results/DCGAN_FAKE/DCGAN_epoch_%03d.png' % (epoch), normalize = True)
    
    #Saving Real image/epoch 
    utils.save_image(real.detach(),'Results/DCGAN_REAL/DCGAN_epoch_%03d.png' % (epoch), normalize = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
#       7     noise = torch.randn(128, 100, 1, 1).to(device)
#       8     fake = gen(noise) #genrator img data
# ---> 10     images = gen(noise,sampleLabel).detach()
#      11 utils.save_image(images.detach(),'Results/DCGAN_FAKE/DCGAN_epoch_%03d.png' % (epoch), normalize = True)
#      13 #Saving Real image/epoch
#
# NameError: name 'sampleLabel' is not defined

# %%
time_end = time.time()
print('elapsed time：%.2f s.'%(time_end-time_start))
# Out:
# elapsed time：5826.33 s.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GLoss,label="Gen")
plt.plot(DLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(image_list[-1],(1,2,0)))
plt.savefig('compare.png')
plt.show()

# %%
print (gen)
# Out:
# Generator(
#   (net): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (4): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Tanh()
#   )
# )
